# %% [markdown]
# # Feature Scaling on Iris Dataset
#
#
# ##  *   Normalization
# ##  *   Standardization

# %% [markdown]
# ### Importing Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %% [markdown]
# ### Reading Dataset using read_csv()

# %%
data = pd.read_csv('/content/Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### Exploring Dataset

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Checking Null Values

# %%
data.isnull().value_counts()
# Out:
# Id     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# False  False          False         False          False         False      150
# dtype: int64

# %% [markdown]
# ## Checking Duplicates

# %%
data.duplicated().value_counts()
# Out:
# False    150
# dtype: int64

# %% [markdown]
# ## Converting Categorical Features into Numeric

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ## Classes:
# * Iris-setosa  0
# * Iris-versicolor 1
# * Iris-virginica   2

# %%
data['Species'] = data['Species'].replace("Iris-setosa", 0)
data['Species'] = data['Species'].replace("Iris-versicolor", 0)
data['Species'] = data['Species'].replace("Iris-virginica", 0)

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        0
# 146  147            6.3           2.5            5.0           1.9        0
# 147  148            6.5           3.0            5.2           2.0        0
# 148  149            6.2           3.4            5.4           2.3        0
# 149  150            5.9           3.0            5.1           1.8        0
#
# [150 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 7.2 KB

# %% [markdown]
# ## Features and Target Variable

# %%
target = pd.DataFrame(data['Species'])

# %%
target
# Out:
#      Species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        0
# 146        0
# 147        0
# 148        0
# 149        0
#
# [150 rows x 1 columns]

# %%
features = data.drop('Species', axis = 1)

# %%
features
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %% [markdown]
# # Feature Scaling - Standardization

# %% [markdown]
# ## By using own Formula

# %%
#features['SepalLengthCm'] = features['SepalLengthCm']-features['SepalLengthCm'].mean()/features['SepalLengthCm'].std()
#features

# %% [markdown]
# ## By Using StandardScaler( )

# %%
#column_headers = ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
#std_scaler = StandardScaler()
#features = pd.DataFrame(std_scaler.fit_transform(features), columns=column_headers)

# %%
#features

# %% [markdown]
# # Feature Scaling - Normalization

# %% [markdown]
# ## By Designing Own Formula

# %%
#features['SepalLengthCm'] = features['SepalLengthCm']-features['SepalLengthCm'].min()/features['SepalLengthCm'].max() - features['SepalLengthCm'].min()
#features

# %% [markdown]
# ## By using MinMaxScaler( )

# %%
column_headers = ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']
minmax_scaler = MinMaxScaler()
features = pd.DataFrame(minmax_scaler.fit_transform(features), columns=column_headers)

# %%
features
# Out:
#            Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0    0.000000       0.222222      0.625000       0.067797      0.041667
# 1    0.006711       0.166667      0.416667       0.067797      0.041667
# 2    0.013423       0.111111      0.500000       0.050847      0.041667
# 3    0.020134       0.083333      0.458333       0.084746      0.041667
# 4    0.026846       0.194444      0.666667       0.067797      0.041667
# ..        ...            ...           ...            ...           ...
# 145  0.973154       0.666667      0.416667       0.711864      0.916667
# 146  0.979866       0.555556      0.208333       0.677966      0.750000
# 147  0.986577       0.611111      0.416667       0.711864      0.791667
# 148  0.993289       0.527778      0.583333       0.745763      0.916667
# 149  1.000000       0.444444      0.416667       0.694915      0.708333
#
# [150 rows x 5 columns]
